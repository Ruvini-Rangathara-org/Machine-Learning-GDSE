# %%
import pandas as pd

df_titanic = pd.read_csv('03 Handling Structural Error_titanic_train.csv')

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0   Third
# 1              2         1   First
# 2              3         1   Third
# 3              4         1   First
# 4              5         0   Third
# ..           ...       ...     ...
# 886          887         0  Second
# 887          888         1   First
# 888          889         0   Third
# 889          890         1   First
# 890          891         0   Third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0  Third
# 1            2         1  First
# 2            3         1  Third
# 3            4         1  First
# 4            5         0  Third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   $7.25    NaN        S
# 1      0          PC 17599  $71.28    C85        C
# 2      0  STON/O2. 3101282   $7.93    NaN        S
# 3      0            113803  $53.10   C123        S
# 4      0            373450   $8.05    NaN        S

# %%
df_titanic.drop(['Name', 'Ticket'], axis=1, inplace=True)

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0  Third    male  22.0      1      0   $7.25    NaN
# 1            2         1  First  female  38.0      1      0  $71.28    C85
# 2            3         1  Third  female  26.0      0      0   $7.93    NaN
# 3            4         1  First  female  35.0      1      0  $53.10   C123
# 4            5         0  Third    male  35.0      0      0   $8.05    NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
df_titanic.shape
# Out:
# (891, 10)

# %%
df_titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass          object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Fare            object
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_titanic.Fare.mean
# Out:
# <bound method Series.mean of 0       $7.25
# 1      $71.28
# 2       $7.93
# 3      $53.10
# 4       $8.05
#         ...
# 886       $13
# 887       $30
# 888    $23.45
# 889       $30
# 890     $7.75
# Name: Fare, Length: 891, dtype: object>

# %%
df_titanic['Fare'] = df_titanic.Fare.str.replace('$', ' ').astype(float)

# %%
df_titanic['Sex_endswith'] = list(map(lambda x: x.endswith(' '), df_titanic['Sex']))
df_titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare Cabin  \
# 0              1         0   Third    male  22.0      1      0   7.25   NaN
# 1              2         1   First  female  38.0      1      0  71.28   C85
# 2              3         1   Third  female  26.0      0      0   7.93   NaN
# 3              4         1   First  female  35.0      1      0  53.10  C123
# 4              5         0   Third    male  35.0      0      0   8.05   NaN
# ..           ...       ...     ...     ...   ...    ...    ...    ...   ...
# 886          887         0  Second    male  27.0      0      0  13.00   NaN
# 887          888         1   First  female  19.0      0      0  30.00   B42
# 888          889         0   Third  female   NaN      1      2  23.45   NaN
# 889          890         1   First    male  26.0      0      0  30.00  C148
# 890          891         0   Third    male  32.0      0      0   7.75   NaN
#
#     Embarked  Sex_endswith
# 0          S         False
# ...

# %%
df_titanic['Sex_startswith'] = list(map(lambda x: x.startswith(' '), df_titanic['Sex']))
df_titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare Cabin  \
# 0              1         0   Third    male  22.0      1      0   7.25   NaN
# 1              2         1   First  female  38.0      1      0  71.28   C85
# 2              3         1   Third  female  26.0      0      0   7.93   NaN
# 3              4         1   First  female  35.0      1      0  53.10  C123
# 4              5         0   Third    male  35.0      0      0   8.05   NaN
# ..           ...       ...     ...     ...   ...    ...    ...    ...   ...
# 886          887         0  Second    male  27.0      0      0  13.00   NaN
# 887          888         1   First  female  19.0      0      0  30.00   B42
# 888          889         0   Third  female   NaN      1      2  23.45   NaN
# 889          890         1   First    male  26.0      0      0  30.00  C148
# 890          891         0   Third    male  32.0      0      0   7.75   NaN
#
#     Embarked  Sex_endswith  Sex_startswith
# ...

# %%
print(df_titanic[df_titanic['Sex_endswith'] == True])
# Out:
#      PassengerId  Survived  Pclass       Sex   Age  SibSp  Parch   Fare Cabin  \
# 342          343         0  Second     male   28.0      0      0  13.00   NaN
# 343          344         0  Second     male   25.0      0      0  13.00   NaN
# 345          346         1  Second   female   24.0      0      0  13.00   F33
# 349          350         0   Third     male   42.0      0      0   8.66   NaN
# 354          355         0   Third     male    NaN      0      0   7.23   NaN
# 374          375         0   Third   female    3.0      3      1  21.08   NaN
# 376          377         1   Third   female   22.0      0      0   7.25   NaN
#
#     Embarked  Sex_endswith  Sex_startswith
# 342        S          True           False
# 343        S          True           False
# 345        S          True           False
# 349        S          True            True
# 354        C          True           False
# 374        S          True            True
# ...

# %%
print(df_titanic[df_titanic['Sex_startswith'] == True])
# Out:
#      PassengerId  Survived  Pclass       Sex   Age  SibSp  Parch    Fare  \
# 0              1         0   Third      male  22.0      1      0    7.25
# 8              9         1   Third    female  27.0      0      2   11.13
# 13            14         0   Third      male  39.0      1      5   31.28
# 31            32         1   First    female   NaN      1      0  146.52
# 48            49         0   Third      male   NaN      2      0   21.68
# 63            64         0   Third      male   4.0      3      2   27.90
# 79            80         1   Third    female  30.0      0      0   12.48
# 128          129         1   Third    female   NaN      1      1   22.36
# 157          158         0   Third      male  30.0      0      0    8.05
# 172          173         1   Third    female   1.0      1      1   11.13
# 204          205         1   Third      male  18.0      0      0    8.05
# 252          253         0   First      male  62.0      0      0   26.55
# ...

# %%
df_titanic.drop(['Sex_endswith', 'Sex_startswith'], axis=1, inplace=True)

# %%
df_titanic['Sex_new'] = list(map(lambda x: x.strip(), df_titanic['Sex']))
df_titanic
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare Cabin  \
# 0              1         0   Third    male  22.0      1      0   7.25   NaN
# 1              2         1   First  female  38.0      1      0  71.28   C85
# 2              3         1   Third  female  26.0      0      0   7.93   NaN
# 3              4         1   First  female  35.0      1      0  53.10  C123
# 4              5         0   Third    male  35.0      0      0   8.05   NaN
# ..           ...       ...     ...     ...   ...    ...    ...    ...   ...
# 886          887         0  Second    male  27.0      0      0  13.00   NaN
# 887          888         1   First  female  19.0      0      0  30.00   B42
# 888          889         0   Third  female   NaN      1      2  23.45   NaN
# 889          890         1   First    male  26.0      0      0  30.00  C148
# 890          891         0   Third    male  32.0      0      0   7.75   NaN
#
#     Embarked Sex_new
# 0          S    male
# ...

# %%
import seaborn as sns

sns.countplot(x='Sex_new', data=df_titanic)
# Out:
# <Axes: xlabel='Sex_new', ylabel='count'>

# %%
df_titanic['Sex_new'].value_counts()
# Out:
# Sex_new
# male      566
# female    303
# fem        11
# mal        11
# Name: count, dtype: int64

# %%
df_titanic ['Sex_new'] = df_titanic['Sex_new'].map({"fem":"female", "mal":"male", "male":"male", "female":"female"})

# %%
sns.countplot(x='Sex_new', data=df_titanic)
# Out:
# <Axes: xlabel='Sex_new', ylabel='count'>

# %%
df_titanic['Sex_new'].value_counts()
# Out:
# Sex_new
# male      577
# female    314
# Name: count, dtype: int64
